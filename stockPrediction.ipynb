# %% [markdown]
# <a href="https://colab.research.google.com/github/devin3706/Car-Rental-System/blob/main/stockPrediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
print(8080)
# Out:
# 8080

# %%
stock_data=pd.read_csv("https://raw.githubusercontent.com/Niwanka/stockPrediction/main/stock_data.csv")

# %%
stock_data.head()
# Out:
#          Date      Open      High       Low     Close  Adj Close     Volume  \
# 0  2000-01-03  4.075000  4.478125  3.952344  4.468750   4.468750  322352000
# 1  2000-01-04  4.268750  4.575000  4.087500  4.096875   4.096875  349748000
# 2  2000-01-05  3.525000  3.756250  3.400000  3.487500   3.487500  769148000
# 3  2000-01-06  3.565625  3.634375  3.200000  3.278125   3.278125  375040000
# 4  2000-01-07  3.350000  3.525000  3.309375  3.478125   3.478125  210108000
#
#   Ticker  RSI  EMA_9  ...  MACD  BB_Lower  BB_Middle  BB_Upper  \
# 0   AMZN  NaN    NaN  ...   NaN       NaN        NaN       NaN
# 1   AMZN  NaN    NaN  ...   NaN       NaN        NaN       NaN
# 2   AMZN  NaN    NaN  ...   NaN       NaN        NaN       NaN
# 3   AMZN  NaN    NaN  ...   NaN       NaN        NaN       NaN
# 4   AMZN  NaN    NaN  ...   NaN       NaN        NaN       NaN
#
#    Inflation Rate (%)  Unemployment Rate (%)  Interest Rate (%)  \
# ...

# %%
report_data=pd.read_csv("https://raw.githubusercontent.com/Niwanka/stockPrediction/main/report_data.csv")

# %%
report_data.head()
# Out:
#    Unnamed: 0        Date  Inflation  Unemployment Rate (%)  Interest Rate (%)
# 0           0  2000-01-01   0.296209                    4.0               5.45
# 1           1  2000-01-02   0.296209                    4.0               5.45
# 2           2  2000-01-03   0.296209                    4.0               5.45
# 3           3  2000-01-04   0.296209                    4.0               5.45
# 4           4  2000-01-05   0.296209                    4.0               5.45

# %%
report_data.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'Inflation', 'Unemployment Rate (%)',
#        'Interest Rate (%)'],
#       dtype='object')

# %%
report_data.drop(columns="Unnamed: 0")
# Out:
#             Date  Inflation  Unemployment Rate (%)  Interest Rate (%)
# 0     2000-01-01   0.296209                    4.0               5.45
# 1     2000-01-02   0.296209                    4.0               5.45
# 2     2000-01-03   0.296209                    4.0               5.45
# 3     2000-01-04   0.296209                    4.0               5.45
# 4     2000-01-05   0.296209                    4.0               5.45
# ...          ...        ...                    ...                ...
# 8517  2023-04-27   0.426852                    3.4               4.83
# 8518  2023-04-28   0.426852                    3.4               4.83
# 8519  2023-04-29   0.426852                    3.4               4.83
# 8520  2023-04-30   0.426852                    3.4               4.83
# 8521  2023-05-01   0.109889                    3.7               5.06
#
# [8522 rows x 4 columns]

# %%
merged_data= pd.merge(stock_data, report_data, on='Date', how='left')

# %%
merged_data.head(60)
# Out:
#           Date      Open      High       Low     Close  Adj Close     Volume  \
# 0   2000-01-03  4.075000  4.478125  3.952344  4.468750   4.468750  322352000
# 1   2000-01-04  4.268750  4.575000  4.087500  4.096875   4.096875  349748000
# 2   2000-01-05  3.525000  3.756250  3.400000  3.487500   3.487500  769148000
# 3   2000-01-06  3.565625  3.634375  3.200000  3.278125   3.278125  375040000
# 4   2000-01-07  3.350000  3.525000  3.309375  3.478125   3.478125  210108000
# 5   2000-01-10  3.628125  3.631250  3.278125  3.459375   3.459375  295158000
# 6   2000-01-11  3.343750  3.500000  3.250000  3.337500   3.337500  210654000
# 7   2000-01-12  3.393750  3.400000  3.150000  3.178125   3.178125  216090000
# 8   2000-01-13  3.246875  3.359375  3.156250  3.296875   3.296875  208962000
# 9   2000-01-14  3.337500  3.431250  3.200000  3.212500   3.212500  137072000
# 10  2000-01-18  3.171875  3.259375  3.150000  3.206250   3.206250  107698000
# ...
